# %% [markdown]
# # TDE Main
# This jupyter notebook contains code to run each primary python file that will reproduce the results in our paper
#
# NOTE: File Rewriting/Saving is turned off by default but can be re-enabled by modifying each file's code where appropiate (a toggle is available in each python file with saving features)
#
# NOTE: Some of the files require user input to continue running.

# %%
# %run TDECatalogMaker
# Out:
# 0
# 	 new 	 	 2MASX J01190869-3411305_Data_2010_07_01
#  	 alt/host 	 GSN 069_Data_2010_07_01
# 1
# 	 new 	 	 2XMM J123103.2+110648_Data_2003_07_13
#  	 alt/host 	 SDSS J123103.24+110648.6_Data_2003_07_13
# 2
# 	 new 	 	 2XMMi J184725.1-631724_Data_2006_09_01
#  	 alt/host 	 IC 4765-f01-1504_Data_2006_09_01
# 3
# 	 new 	 	 3XMM J150052.0+015452_Data_2005_07_23
#  	 alt/host 	 SDSS J150052.07+015453.8_Data_2005_07_23
# 4
# 	 new 	 	 3XMM J152130.7+074916_Data_2000_08_23
#  	 alt/host 	 SDSS J152130.72+074916.5_Data_2000_08_23
# 5
# 	 new 	 	 3XMM J215022.4-055108_Data_2005_05_01
#  	 alt/host 	 6dFGS gJ215022.2-055059_Data_2005_05_01
# 6
# 	 new 	 	 ASASSN-14ae_Data_2014_01_25
#  	 alt/host 	 SDSS J110840.11+340552.2_Data_2014_01_25
# 7
# 	 new 	 	 ASASSN-14li_Data_2014_11_22
#  	 alt/host 	 SDSS J124815.23+174626.4_Data_2014_11_22
# 8
# 	 new 	 	 ASASSN-15lh_Data_2015_06_14
#  	 alt/host 	 APMUKS (BJ) B215839.70-615403.9_Data_2015_06_14
# 9
# 	 new 	 	 ASASSN-15oi_Data_2015_08_14
# ...

# %%
# %run PriorityTDEFilter
# Out:
# Database index:  2
# 154
# YES, Obs within 3000 days:  154
# 2MASX J01190869-3411305
# 1618
# YES, Obs within 3000 days:  1618
# 2MASX J01190869-3411305
# 3098
# 3121
# 3256
# 3480
# 3619
# 3625
# 3635
# 3635
# ...
# Database index:  3
# 0
# YES, Obs within 3000 days:  0
# 2XMM J123103.2+110648
# YES, Obs within 100 days:  0
# 2XMM J123103.2+110648
# 884
# YES, Obs within 3000 days:  884
# 2XMM J123103.2+110648
# 888
# YES, Obs within 3000 days:  888
# 2XMM J123103.2+110648
# 885
# YES, Obs within 3000 days:  885
# 2XMM J123103.2+110648
# 889
# YES, Obs within 3000 days:  889
# 2XMM J123103.2+110648
# ...
# Database index:  4
# 5
# YES, Obs within 3000 days:  5
# 2XMMi J184725.1-631724
# YES, Obs within 100 days:  5
# 2XMMi J184725.1-631724
# 2375
# YES, Obs within 3000 days:  2375
# 2XMMi J184725.1-631724
# 227
# YES, Obs within 3000 days:  227
# 2XMMi J184725.1-631724
# ...
# Database index:  5
# 0
# YES, Obs within 3000 days:  0
# 3XMM J150052.0+015452
# YES, Obs within 100 days:  0
# ...

# %%
# %run TDETimelineMaker
# Out:
#  0 2MASX J01190869-3411305_Data_2010_07_01
# 2MASX J01190869-3411305_XMM_Data_2010_07_01.txt
# 2MASX J01190869-3411305_Swift_Data_2010_07_01.txt
# 2MASX J01190869-3411305_Chandra_Data_2010_07_01.txt
#
#  1 2XMM J123103.2+110648_Data_2003_07_13
# 2XMM J123103.2+110648_Swift_Data_2003_07_13.txt
# 2XMM J123103.2+110648_Chandra_Data_2003_07_13.txt
# 2XMM J123103.2+110648_XMM_Data_2003_07_13.txt
#
#  2 2XMMi J184725.1-631724_Data_2006_09_01
# 2XMMi J184725.1-631724_XMM_Data_2006_09_01.txt
# 2XMMi J184725.1-631724_Chandra_Data_2006_09_01.txt
# 2XMMi J184725.1-631724_Swift_Data_2006_09_01.txt
#
#  3 3XMM J150052.0+015452_Data_2005_07_23
# 3XMM J150052.0+015452_Chandra_Data_2005_07_23.txt
# 3XMM J150052.0+015452_Swift_Data_2005_07_23.txt
# 3XMM J150052.0+015452_XMM_Data_2005_07_23.txt
#
#  4 3XMM J152130.7+074916_Data_2000_08_23
# 3XMM J152130.7+074916_Chandra_Data_2000_08_23.txt
# 3XMM J152130.7+074916_Swift_Data_2000_08_23.txt
# 3XMM J152130.7+074916_XMM_Data_2000_08_23.txt
#
# ...

# %%
# %run TDERedshiftExpTimePlotter
